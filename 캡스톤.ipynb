# %% [markdown]
# <a href="https://colab.research.google.com/github/kdHyeok/VS-Code_History/blob/master/%EC%BA%A1%EC%8A%A4%ED%86%A4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
from concurrent.futures import ThreadPoolExecutor
from datetime import datetime

from datetime import datetime
from urllib.parse import urljoin
import re

def crawl_page(limit, offset):
    url = f"https://www.jj.ac.kr/jj/community/notice01.do?mode=list&&articleLimit={limit}&article.offset={offset}"
    try:
        res = requests.get(url, timeout=5)
        res.encoding = 'utf-8'
        res.raise_for_status()
    except Exception as e:
        print(f"[!] 요청 실패 (offset={offset}) → {e}")
        return []

    soup = bs(res.text, "html.parser")
    box = soup.find("tbody")
    rows = []

    if not box:
        return rows

    for tr in box.find_all("tr"):
        tds = tr.find_all("td")
        if len(tds) < 2:
            continue

        no = tds[0].text.strip()
        content_td = tds[1]

        # 제목
        a_tag = content_td.select_one("div > div > a")
        title = ' '.join(a_tag.stripped_strings) if a_tag else None

        # 링크
        href = a_tag.get("href") if a_tag else None
        link = urljoin("https://www.jj.ac.kr/jj/community/notice01.do", href) if href else None

        # 부서
        dept_span = content_td.select_one("div > div:nth-of-type(3) > span.b-writer")
        dept = dept_span.text.strip() if dept_span else None

        # 게시일
        date_span = content_td.select_one("div > div:nth-of-type(3) > span.b-date")
        date = date_span.text.strip() if date_span else None

        # 조회수
        hit_span = content_td.select_one("div > div:nth-of-type(3) > span.b-hit")
        if hit_span:
            hit_text = hit_span.text.strip()
            match = re.search(r'\d+', hit_text)
            views = int(match.group()) if match else 0
        else:
            views = 0

        # 상단 고정 공지 처리
        if no == "공지":
            if not dept:
                dept = "관리자"
            date = datetime.today().strftime('%Y-%m-%d')
            if views == 0:
                views = 0

        if title:
            rows.append({
                "등록 번호": no,
                "공지 제목": title,
                "부서": dept,
                "등록일": date,
                "조회수": views,
                "링크": link
            })

    return rows

# %%
# 전체 페이지 병렬 크롤링 + 중복 제거
def gongji_crawl_parallel(limit=100, max_pages=80):
    offsets = [page * limit for page in range(max_pages)]
    all_rows = []

    with ThreadPoolExecutor(max_workers=10) as executor:
        results = list(executor.map(lambda offset: crawl_page(limit, offset), offsets))

    for page_rows in results:
        all_rows.extend(page_rows)

    # DataFrame 생성 및 중복 제거
    df = pd.DataFrame(all_rows)
    df.drop_duplicates(subset=["등록 번호", "공지 제목"], inplace=True)

    return df

# %%
pd.set_option('display.max_colwidth', None)
df = gongji_crawl_parallel(limit=100, max_pages=10)

# %%
df.head(50)
# Out:
#    등록 번호                                                 공지 제목            부서  \
# 0     공지                           2025학년도 SUPER 핵심역량 진단 참여 안내           관리자
# 1     공지                                     제13회 미래전북포럼 개최 안내           관리자
# 2     공지                     2025학년도 1학기 직장(학생)예비군 전입신고서 제출 안내           관리자
# 3   7490                               전주대학교 캠퍼스 '낭만 사진 작가' 모집       대외협력홍보실
# 4   7489                      [교수학습개발센터] 2025-1학기 JJ같이아는 학습동아리      교수학습개발센터
# 5   7488                    [전북생명의전화] 2025년 대학생 전화상담사 양성교육생 모집           관리자
# 6   7487              졸업생 맞춤형 취업지원 프로그램 [졸업생 밸류업 특공대] 신청 모집 안내  대학일자리플러스센터 일
# 7   7486             「2025학년도 1학기 JST 공유대학 평생교육 온라인 콘텐츠 운영」 안내        RIS사업단
# 8   7485                             신축 평화관별관 CCTV 설치에 따른 행정예고         시설지원실
# 9   7484               [졸업생 특화] 전주고용센터와 함께하는 성취 프로그램 4월 참여자 모집    대학일자리플러스센터
# 10  7483                                       Eduroam(에듀롬) 안내           관리자
# 11  7482  [교수학습개발센터] 2025-1학기 AI 활용 맞춤형 A+ 받는 레포트 글쓰기 교실 운영 안내      교수학습개발센터
# 12  7481                   [교수학습개발센터] 2025-1학기  JJ학습법 특강 운영 안내      교수학습개발센터
# 13  7480                         2025-1학기 진로 해시태그 프로그램 추가 모집안내        진로개발센터
# 14  7479                             전주대학교 백마응원단에서 신입단원을 모집합니다         학생지원실
# 15  7478                         2025학년도 총장님과 함께하는 학사모니터 모집 홍보         학생지원실
# 16  7477                   [마감] 전주대학교 대학혁신지원사업 서포터즈 JUNI:ON 모집     대학혁신지원사업단
# 17  7476                     2025학년도 1학기 직장(학생)예비군 전입신고서 제출 안내           관리자
# 18  7475             2026-2027년도 풀브라이트 미국 대학원 유학 장학 프로그램 선발 안내         국제교류원
# 19  7474            [원격교육지원센터] 2025-1학기 전주대학교 MOOC 수강신청 이벤트 안내      원격교육지원센터
# 20  7473                [인권센터] 2025학년도 인권센터 서포터즈 4기 2차 추가모집 안내          인권센터
# 21  7472                      2025-1학기 디지털역량강화교육 컴퓨터활용능력 2급 필기    대학일자리플러스센터
# 22  7471                          「청년 해외기업 인턴십 지원사업」 참여자 모집 안내         국제교류원
# 23  7470                      2025학년도 도내우수 기업 모니터링단(4기) 참여자 모집    대학일자리플러스센터
# 24  7469                                 2025 StarT Program 안내        진로개발센터
# 25  7468                [사회봉사센터] 2025-1학기 전공 연계형 봉사활동 지원 사업 공고        사회봉사센터
# 26  7467                    [사회봉사센터] 2025학년도 전주대학교 학생봉사단 모집 안내        사회봉사센터
# 27  7466       [교수학습개발센터] 2025-1학기 학사경고자 지원 프로그램 LAMP ON 모집 안내      교수학습개발센터
# 28  7465   [대학일자리플러스센터] JJ 취업 서포터즈(10기) 모집 안내: 1~4학년 모두 참여 가능!    대학일자리플러스센터
# 29  7464                         [교수학습개발센터] 2025-1학기  학습컨설팅 안내      교수학습개발센터
# 30  7463                                    2025년도 대학안전관리계획 안내         총무지원실
# 31  7462                                 『좋은친구 또래상담』 14기 모집 공고        카운슬링센터
# 32  7461                                 전주시 청년자율방재단 제2기 모집 안내       대외협력홍보실
# 33  7460                             [교수학습개발센터] 편입생 학업적응 특강 안내      교수학습개발센터
# 34  7459                             [교수학습개발센터] 복학생 학업적응 특강 안내      교수학습개발센터
# 35  7458                             2025-1학기 진로 해시태그(#) 모집 안내        진로개발센터
# 36  7457                                2025학년도 1학기  글로벌라운지 안내       수퍼스타칼리지
# 37  7456                            2025학년도 1학기 평점 올리기 트랙신청 안내        진로개발센터
# 38  7455               2025-1학기 디지털역량강화교육 ACP포토샵&일러스트레이터 모집 안내    대학일자리플러스센터
# 39  7454           [대외협력홍보실] 2025학년도 전주대학교 홍보대사 모집(~3. 12.(수))       대외협력홍보실
# 40  7453                     2025년 상반기 한미 대학생 연수(WEST) 프로그램 안내         국제교류원
# 41  7452           [교수학습개발센터] 학습전략워크숍(JJ 코넬노트, JJ 학습플래너) 운영 안내      교수학습개발센터
# 42  7451              [교수학습개발센터] 학사경고자 지원 프로그램 징검다리 프로젝트 모집 안내      교수학습개발센터
# 43  7450  [소재응용연구소]다공성 탄소소재 기반 환경 소재 및 부품 개발  전문인력양성 교육생 모집 공고           관리자
# 44  7449             진로취업지원실 2025-1학기 디지털역량강화교육 컴퓨터 자격증반 일정 안내    대학일자리플러스센터
# 45  7448                      [교수학습개발센터] 2025-1학기 교수지원 프로그램 안내      교수학습개발센터
# 46  7447                     [인권센터] 2025학년도 인권센터 서포터즈 4기 모집 안내          인권센터
# 47  7446                         [전주시가족센터] 2025 대학생 학비지원 모집 안내         학생지원실
# 48  7445                                    2030 청년 무료 건강검진 안내         학생지원실
# 49  7444                      2025학년도 장애인식개선 서포터즈 C.T.C. 모집 안내      장애학생지원센터
#
#            등록일   조회수  \
# 0   2025-03-27     0
# 1   2025-03-27     0
# 2   2025-03-27     0
# 3   2025-03-26   194
# 4   2025-03-26   205
# 5   2025-03-26   126
# 6   2025-03-25   118
# 7   2025-03-24   141
# 8   2025-03-23   141
# 9   2025-03-21   444
# 10  2025-03-18   495
# 11  2025-03-17  1029
# 12  2025-03-17   319
# 13  2025-03-17   360
# 14  2025-03-17   317
# 15  2025-03-17   733
# 16  2025-03-17   679
# 17  2025-03-13   146
# 18  2025-03-13   196
# 19  2025-03-13   135
# 20  2025-03-12   171
# 21  2025-03-12   213
# 22  2025-03-12   210
# 23  2025-03-12   163
# 24  2025-03-12   200
# 25  2025-03-12   160
# 26  2025-03-12   162
# 27  2025-03-12   135
# 28  2025-03-12   228
# 29  2025-03-07   275
# 30  2025-03-06   211
# 31  2025-03-06   331
# 32  2025-03-04   430
# 33  2025-03-04   191
# 34  2025-03-04   249
# 35  2025-03-04   295
# 36  2025-03-04   354
# 37  2025-03-04   456
# 38  2025-02-28   421
# 39  2025-02-28   953
# 40  2025-02-28   518
# 41  2025-02-25   967
# 42  2025-02-25   424
# 43  2025-02-24   230
# 44  2025-02-19   671
# 45  2025-02-19   674
# 46  2025-02-18   590
# 47  2025-02-18  1060
# 48  2025-02-17  1074
# 49  2025-02-14   525
#
#                                                                                                             링크
# 0   https://www.jj.ac.kr/jj/community/notice01.do?mode=view&articleNo=478197&article.offset=0&articleLimit=100
# 1   https://www.jj.ac.kr/jj/community/notice01.do?mode=view&articleNo=478010&article.offset=0&articleLimit=100
# 2   https://www.jj.ac.kr/jj/community/notice01.do?mode=view&articleNo=188625&article.offset=0&articleLimit=100
# 3   https://www.jj.ac.kr/jj/community/notice01.do?mode=view&articleNo=478268&article.offset=0&articleLimit=100
# 4   https://www.jj.ac.kr/jj/community/notice01.do?mode=view&articleNo=478257&article.offset=0&articleLimit=100
# 5   https://www.jj.ac.kr/jj/community/notice01.do?mode=view&articleNo=478211&article.offset=0&articleLimit=100
# 6   https://www.jj.ac.kr/jj/community/notice01.do?mode=view&articleNo=478205&article.offset=0&articleLimit=100
# 7   https://www.jj.ac.kr/jj/community/notice01.do?mode=view&articleNo=478077&article.offset=0&articleLimit=100
# 8   https://www.jj.ac.kr/jj/community/notice01.do?mode=view&articleNo=478069&article.offset=0&articleLimit=100
# 9   https://www.jj.ac.kr/jj/community/notice01.do?mode=view&articleNo=478052&article.offset=0&articleLimit=100
# 10  https://www.jj.ac.kr/jj/community/notice01.do?mode=view&articleNo=477830&article.offset=0&articleLimit=100
# 11  https://www.jj.ac.kr/jj/community/notice01.do?mode=view&articleNo=477789&article.offset=0&articleLimit=100
# 12  https://www.jj.ac.kr/jj/community/notice01.do?mode=view&articleNo=477777&article.offset=0&articleLimit=100
# 13  https://www.jj.ac.kr/jj/community/notice01.do?mode=view&articleNo=477774&article.offset=0&articleLimit=100
# 14  https://www.jj.ac.kr/jj/community/notice01.do?mode=view&articleNo=477764&article.offset=0&articleLimit=100
# 15  https://www.jj.ac.kr/jj/community/notice01.do?mode=view&articleNo=477763&article.offset=0&articleLimit=100
# 16  https://www.jj.ac.kr/jj/community/notice01.do?mode=view&articleNo=477762&article.offset=0&articleLimit=100
# 17  https://www.jj.ac.kr/jj/community/notice01.do?mode=view&articleNo=477707&article.offset=0&articleLimit=100
# 18  https://www.jj.ac.kr/jj/community/notice01.do?mode=view&articleNo=477706&article.offset=0&articleLimit=100
# 19  https://www.jj.ac.kr/jj/community/notice01.do?mode=view&articleNo=477705&article.offset=0&articleLimit=100
# 20  https://www.jj.ac.kr/jj/community/notice01.do?mode=view&articleNo=477661&article.offset=0&articleLimit=100
# 21  https://www.jj.ac.kr/jj/community/notice01.do?mode=view&articleNo=477660&article.offset=0&articleLimit=100
# 22  https://www.jj.ac.kr/jj/community/notice01.do?mode=view&articleNo=477659&article.offset=0&articleLimit=100
# 23  https://www.jj.ac.kr/jj/community/notice01.do?mode=view&articleNo=477658&article.offset=0&articleLimit=100
# 24  https://www.jj.ac.kr/jj/community/notice01.do?mode=view&articleNo=477657&article.offset=0&articleLimit=100
# 25  https://www.jj.ac.kr/jj/community/notice01.do?mode=view&articleNo=477656&article.offset=0&articleLimit=100
# 26  https://www.jj.ac.kr/jj/community/notice01.do?mode=view&articleNo=477654&article.offset=0&articleLimit=100
# 27  https://www.jj.ac.kr/jj/community/notice01.do?mode=view&articleNo=477653&article.offset=0&articleLimit=100
# 28  https://www.jj.ac.kr/jj/community/notice01.do?mode=view&articleNo=477652&article.offset=0&articleLimit=100
# 29  https://www.jj.ac.kr/jj/community/notice01.do?mode=view&articleNo=188650&article.offset=0&articleLimit=100
# 30  https://www.jj.ac.kr/jj/community/notice01.do?mode=view&articleNo=188649&article.offset=0&articleLimit=100
# 31  https://www.jj.ac.kr/jj/community/notice01.do?mode=view&articleNo=188648&article.offset=0&articleLimit=100
# 32  https://www.jj.ac.kr/jj/community/notice01.do?mode=view&articleNo=188647&article.offset=0&articleLimit=100
# 33  https://www.jj.ac.kr/jj/community/notice01.do?mode=view&articleNo=188646&article.offset=0&articleLimit=100
# 34  https://www.jj.ac.kr/jj/community/notice01.do?mode=view&articleNo=188645&article.offset=0&articleLimit=100
# 35  https://www.jj.ac.kr/jj/community/notice01.do?mode=view&articleNo=188643&article.offset=0&articleLimit=100
# 36  https://www.jj.ac.kr/jj/community/notice01.do?mode=view&articleNo=188644&article.offset=0&articleLimit=100
# 37  https://www.jj.ac.kr/jj/community/notice01.do?mode=view&articleNo=188642&article.offset=0&articleLimit=100
# 38  https://www.jj.ac.kr/jj/community/notice01.do?mode=view&articleNo=188641&article.offset=0&articleLimit=100
# 39  https://www.jj.ac.kr/jj/community/notice01.do?mode=view&articleNo=188640&article.offset=0&articleLimit=100
# 40  https://www.jj.ac.kr/jj/community/notice01.do?mode=view&articleNo=188639&article.offset=0&articleLimit=100
# 41  https://www.jj.ac.kr/jj/community/notice01.do?mode=view&articleNo=188637&article.offset=0&articleLimit=100
# 42  https://www.jj.ac.kr/jj/community/notice01.do?mode=view&articleNo=188638&article.offset=0&articleLimit=100
# 43  https://www.jj.ac.kr/jj/community/notice01.do?mode=view&articleNo=188636&article.offset=0&articleLimit=100
# 44  https://www.jj.ac.kr/jj/community/notice01.do?mode=view&articleNo=188635&article.offset=0&articleLimit=100
# 45  https://www.jj.ac.kr/jj/community/notice01.do?mode=view&articleNo=188634&article.offset=0&articleLimit=100
# 46  https://www.jj.ac.kr/jj/community/notice01.do?mode=view&articleNo=188633&article.offset=0&articleLimit=100
# 47  https://www.jj.ac.kr/jj/community/notice01.do?mode=view&articleNo=188632&article.offset=0&articleLimit=100
# 48  https://www.jj.ac.kr/jj/community/notice01.do?mode=view&articleNo=188631&article.offset=0&articleLimit=100
# 49  https://www.jj.ac.kr/jj/community/notice01.do?mode=view&articleNo=188630&article.offset=0&articleLimit=100

# %% [markdown]
# # ***크롤링 테스트***

# %%
# !pip install selenium
# !apt-get update
# !apt install chromium-chromedriver
# !cp /usr/lib/chromium-browser/chromedriver /usr/bin
# Out:
# ERROR: Operation cancelled by user
# Hit:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Fetched 257 kB in 1s (238 kB/s)
# ^C
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# chromium-chromedriver is already the newest version (1:85.0.4183.83-0ubuntu2.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.
# cp: '/usr/lib/chromium-browser/chromedriver' and '/usr/bin/chromedriver' are the same file

# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd

def gongji_print(n, m):
    # 공지사항 URL 구성
    gongji_url = f"https://www.jj.ac.kr/jj/community/notice01.do?mode=list&&articleLimit={n}&article.offset={m}"
    raw = requests.get(gongji_url)
    raw.encoding = 'utf-8'  # 인코딩 명시
    soup = bs(raw.text, "html.parser")

    # 결과 저장용 리스트
    rows = []

    # 공지 테이블 추출
    box = soup.find("tbody")
    for tr in box.find_all("tr"):
        # 등록 번호
        td_list = tr.find_all("td")
        if len(td_list) < 2:
            continue
        no = td_list[0].text.strip()

        # 제목 추출
        a_tag = tr.select_one("td:nth-of-type(2) a")
        if a_tag:
            title = ' '.join(a_tag.stripped_strings)
            rows.append({"등록 번호": no, "공지 제목": title})

    return pd.DataFrame(rows)

# 실행
df = gongji_print(100, 0)
df
# Out:
#     등록 번호                                          공지 제목
# 0      공지                    2025학년도 SUPER 핵심역량 진단 참여 안내
# 1      공지                              제13회 미래전북포럼 개최 안내
# 2      공지              2025학년도 1학기 직장(학생)예비군 전입신고서 제출 안내
# 3    7490                        전주대학교 캠퍼스 '낭만 사진 작가' 모집
# 4    7489               [교수학습개발센터] 2025-1학기 JJ같이아는 학습동아리
# ..    ...                                            ...
# 98   7395                       [산학협력단] 제9회 미래전북포럼 개최 안내
# 99   7394  [산학혁협력단] 제10회 미래전북포럼(2024 하우와우미래캠프 워크숍) 개최 안내
# 100  7393                          임금협약을 위한 단체교섭 요구사실 공고
# 101  7392        [원격교육지원센터] 2024년 JJ 공개강좌 페스티벌 안내(경품 증정)
# 102  7391                          2025학년도 학생자치기구장 선거 알림
#
# [103 rows x 2 columns]

# %% [markdown]
# ### gpt-test

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# 1. 공지사항 페이지 URL
url = "https://www.jj.ac.kr/jj/community/notice01.do"

# 2. 페이지 요청 및 파싱
response = requests.get(url)
response.encoding = 'utf-8'
soup = BeautifulSoup(response.text, "html.parser")

# 3. 공지사항 제목 추출 (a 태그 중 data-article-no 속성이 있는 것)
notice_links = soup.select('a[data-article-no]')

# 4. 텍스트만 추출해서 리스트로 저장
titles = [link.get_text(strip=True) for link in notice_links]

# 5. pandas DataFrame으로 변환
df = pd.DataFrame(titles, columns=['공지 제목'])

# 6. 출력
df
# Out:
#                                                 공지 제목
# 0                         2025학년도 SUPER 핵심역량 진단 참여 안내
# 1                                   제13회 미래전북포럼 개최 안내
# 2                   2025학년도 1학기 직장(학생)예비군 전입신고서 제출 안내
# 3                             전주대학교 캠퍼스 '낭만 사진 작가' 모집
# 4                    [교수학습개발센터] 2025-1학기 JJ같이아는 학습동아리
# 5                  [전북생명의전화] 2025년 대학생 전화상담사 양성교육생 모집
# 6            졸업생 맞춤형 취업지원 프로그램 [졸업생 밸류업 특공대] 신청 모집 안내
# 7           「2025학년도 1학기 JST 공유대학 평생교육 온라인 콘텐츠 운영」 안내
# 8                           신축 평화관별관 CCTV 설치에 따른 행정예고
# 9             [졸업생 특화] 전주고용센터와 함께하는 성취 프로그램 4월 참여자 모집
# 10                                    Eduroam(에듀롬) 안내
# 11  [교수학습개발센터] 2025-1학기 AI 활용 맞춤형 A+ 받는 레포트 글쓰기 교실...
# 12                [교수학습개발센터] 2025-1학기  JJ학습법 특강 운영 안내
# 13                      2025-1학기 진로 해시태그 프로그램 추가 모집안내
# 14                          전주대학교 백마응원단에서 신입단원을 모집합니다
# 15                      2025학년도 총장님과 함께하는 학사모니터 모집 홍보
# 16                [마감] 전주대학교 대학혁신지원사업 서포터즈 JUNI:ON 모집
# 17                  2025학년도 1학기 직장(학생)예비군 전입신고서 제출 안내
# 18          2026-2027년도 풀브라이트 미국 대학원 유학 장학 프로그램 선발 안내
# 19         [원격교육지원센터] 2025-1학기 전주대학교 MOOC 수강신청 이벤트 안내
# 20             [인권센터] 2025학년도 인권센터 서포터즈 4기 2차 추가모집 안내
# 21                   2025-1학기 디지털역량강화교육 컴퓨터활용능력 2급 필기
# 22                       「청년 해외기업 인턴십 지원사업」 참여자 모집 안내
